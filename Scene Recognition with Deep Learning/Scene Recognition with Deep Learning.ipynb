# %% [markdown]
# # Scene Recognition with Deep Learning
#
# ## Brief
# - Due
#     - Part 1 Code 09/30/2020 11:59PM (released earlier)
#     - Part 2 Code 10/13/2020 11:59PM (this notebook)
#     - Report 10/13/2020 11:59PM (in the zip)
# - Hand-in: through Gradescope
# - Required files:
#     - `<your_gt_username>.zip` against [Project 2 - Part 2 - Code (Individual)](https://www.gradescope.com/courses/155064/assignments/699611) or [Project 2 - Part 2 - Code (Partner)](https://www.gradescope.com/courses/155064/assignments/699616/)
#     - PDF report against [Project 2 - Report](https://www.gradescope.com/courses/155064/assignments/699620)
#
# ### Note:
# 1. Working on pairs and individual submissions have already been decided. You cannot switch now.
# 2. You need to copy-paste your all the .py files from the part 1.

# %% [markdown]
# ## Outline
# In this project, we will use *convolutional neural nets* to classify images into different scenes.
#
# Basic learning objectives of this project:
# 1. Construct the fundamental pipeline for performing deep learning using PyTorch;
# 2. Understand the concepts behind different layers, optimizers.
# 3. Experiment with different models and observe the performance.
#
# The starter code is mostly initialized to 'placeholder' just so that the starter
# code does not crash when run unmodified and you can get a preview of how
# results are presented.
#
# ## Compute Requirements
#
# This project is doable without a GPU, but a GPU makes the process much more faster and frustration free.
#
# You can try out Google Colab to run this notebook. These are the steps we follow:
# 1. Upload this notebook to google colab
# 2. Zip all the components in the project directory and upload it to the colab runtime
# 3. Unzip the uploaded zip using ```!unzip -qq <uploaded_file>.zip -d ./```
#
# Remember to download all the files saved and changes to code you made on the colab.
#
# Note that we will not be actively supporting issues with Google colab. Please take help from fellow students and use the internet to solve the issues.

# %% [markdown]
# ## Dataset
# The dataset is in the ```data``` folder. It has two subfolders: ```train``` and ```test```. Go through any of the folder and find there you will find the folders with scene names like *bedroom*, *forest*, *office*. These are the 15 scenes that we want our model to predict given an RGB image. You can look into folder for each scene to find multiple images. All this data is labelled data provided to you for training and testing your model.
#
# **Let's start coding now!**

# %% [markdown]
# ## Setup

# %%
# uncomment for running on colab
# !unzip -qq proj2_colab.zip -d ./
# Out:
# replace ./6476_Fall2020_proj2.egg-info/dependency_links.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# flag to modify paths to run better on Colab; change it to true if you want to run on colab
use_colab_paths = True

# %% [markdown]
# ## Dataset
# The dataset is in the ```data``` folder. It has two subfolders: ```train``` and ```test```. Go through any of the folder and find there you will find the folders with scene names like *bedroom*, *forest*, *office*. These are the 15 scenes that we want our model to predict given an RGB image. You can look into folder for each scene to find multiple images. All this data is labelled data provided to you for training and testing your model.
#
# **Let's start coding now!**

# %% [markdown]
# ## Setup

# %%
import os
import torch
import matplotlib.pyplot as plt

from proj2_code.runner import Trainer
from proj2_code.optimizer import get_optimizer
from proj2_code.simple_net import SimpleNet
from proj2_code.simple_net_dropout import SimpleNetDropout
from proj2_code.my_alexnet import MyAlexNet
from proj2_code.image_loader import ImageLoader
from proj2_code.data_transforms import get_fundamental_transforms, get_data_augmentation_transforms
from proj2_code.stats_helper import compute_mean_and_std
from proj2_code.vis import visualize

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from proj2_code.proj2_unit_tests.test_base import verify
from proj2_code.proj2_unit_tests.test_stats_helper import test_mean_and_variance
from proj2_code.proj2_unit_tests.test_image_loader import test_dataset_length, test_unique_vals, test_class_values, test_load_img_from_path
from proj2_code.proj2_unit_tests.test_data_transforms import test_fundamental_transforms
from proj2_code.proj2_unit_tests.test_dl_utils import test_predict_labels, test_compute_loss
from proj2_code.proj2_unit_tests.test_simple_net import test_simple_net
from proj2_code.proj2_unit_tests.test_simple_net_dropout import test_simple_net_dropout
from proj2_code.proj2_unit_tests.test_my_alexnet import test_my_alexnet
from proj2_code.proj2_unit_tests.test_checkpoints import test_simple_net_checkpoint

# %%
is_cuda = True
is_cuda = is_cuda and torch.cuda.is_available() # will turn off cuda if the machine doesnt have a GPU

# %%
data_base_path = '../data/' if not use_colab_paths else 'data/'
model_base_path = '../model_checkpoints/' if not use_colab_paths else 'model_checkpoints/'

# %%
print(os.listdir(data_base_path))
print(os.listdir(model_base_path))

# TODO: check that these outputs are as per expectation. It will save a lot of time in debugging issues.
# Out:
# ['train', 'test']
# ['simple_net_ablation', 'simple_net_dropout', 'quantized_alexnet', 'simple_net', 'alexnet']

# %% [markdown]
# To train a network in PyTorch, we need 4 components:
# 1. **Dataset** - an object which can load the data and labels given an index.
# 2. **Model** - an object that contains the network architecture definition.
# 3. **Loss function** - a function that measures how far the network output is from the ground truth label.
# 4. **Optimizer** - an object that optimizes the network parameters to reduce the loss value.

# %% [markdown]
# ## 1 Datasets
# One crucial aspect of deep learning is to perform data preprocessing. In DL, we usually *normalize* the dataset and perform some *transformations* on them. The transformations can either help the inputs be compatible with the model (say our model only works on 500x500 images and we need all input to be cropped/scaled to this size) or help in data-augmentation to improve performance (more on this later).
#
#
# ### 1.1 Compute mean and standard deviation of the dataset
# In this project we are going to "zero-center" and "normalize" the dataset so that each entry has zero mean and the overall standard deviation is 1.
#
# **TODO 1**:  fill in the `compute_mean_and_std()` in `stats_helper.py` to compute the **mean** and **standard deviation** of both training and validation data.
#
# Debug tip: If you face an error from StandardScaler about attribute not found, please check that the paths are correct and your code actually finds some images.

# %%
print("Testing your mean and std computation: ", verify(test_mean_and_variance))
dataset_mean, dataset_std = compute_mean_and_std(data_base_path)
# Out:
# Testing your mean and std computation:  "Correct"

# %%
print('Dataset mean = {}, standard deviation = {}'.format(dataset_mean, dataset_std))
# Out:
# Dataset mean = [0.45547487], standard deviation = [0.25316328]

# %% [markdown]
# ### 1.2 ImageLoader
#
# Now let's create the **Datasets** object to be used later. Remember back in Project 1, we have initialized such a class to load 5 images? Here the task is similar: we have to load each image as well as it's classification label. The essence is to retrieve the paths to all the images required, and be able to provide the **path** and the **class id** when given an index.
#
# We will map the scene names (text) into indices 0 to 14 in the image loader. You can choose any mapping you want but once fixed, it has to be consistent throughout this notebook.
#
# **TODO 2:** complete the `image_loader.py`

# %%
inp_size = (64,64)
print("Testing your image loader (length):", verify(test_dataset_length))
print("Testing your image loader (values):", verify(test_unique_vals))
print("Testing your image loader (classes):", verify(test_class_values))
print("Testing your image loader (paths):", verify(test_load_img_from_path))
# Out:
# Testing your image loader (length): "Correct"
# Testing your image loader (values): "Correct"
# Testing your image loader (classes): "Correct"
# Testing your image loader (paths): "Correct"

# %% [markdown]
# ### 1.3 Data transforms
# In this section, we will construct some fundamental transforms to process RGB images into torch tensors, which we can provide as input to our model.
#
# 1. Resize the input image to the desired shape;
# 2. Convert it to a tensor;
# 3. Normalize them based on the computed mean and standard deviation.
#
# **TODO 3:** For this part, complete the function `get_fundamental_transforms()` in `data_transforms.py`

# %%
print("Testing your fundamental data transforms: ", verify(test_fundamental_transforms))
# Out:
# Testing your fundamental data transforms:  "Correct"

# %% [markdown]
# ## 2 Model Architecture and Forward Pass

# %% [markdown]
# ### 2.1 SimpleNet Model
#
# The data is ready! Now we are preparing to move to the actual core of deep learning: the architecture. To get you started in this part, simply define a **2-layer** model in the `simple_net.py`. Here by "2 layers" we mean **2 convolutional layers**, so you need to figure out the supporting utilities like ReLU, Max Pooling, and Fully Connected layers, and configure them with proper parameters to make the tensor flow.
#
# You may refer the image *simplenet.jpg* in the base folder for a sample network architecture (it's the architecture TAs used in their implementation and is sufficient to get you pass Part 1).
#
# **TODO 4**: Do the following in ```simple_net.py```:
# - Initialize ```self.cnn_layers```
# - Initialize ```self.fc_layers```
# - Write the forward function
#
# Leave the ```self.loss_criterion = None``` for now.

# %%
print("Testing your SimpleNet architecture: ", verify(test_simple_net))
# Out:
# Testing your SimpleNet architecture:  "Correct"

# %% [markdown]
# ### 2.2 Output prediction

# %% [markdown]
# Let's see what out model's forward function produces for a sample input, and how it relates to classification. Pytorch's convolution and FC layers are initialized with random weights. So we should not expect any useful output without any training.
#
# We will use a data-point from the dataloader we have already created and run the model on it.

# %%
simple_model = SimpleNet()

image_loader = ImageLoader(data_base_path, 
                           split='train', 
                           transform=get_fundamental_transforms(inp_size, dataset_mean, dataset_std)
                          )

# %%
# get the 0th sample
sample_image, sample_label = next(iter(image_loader))

# %%
print('Input image shape = ', sample_image.shape)
# Out:
# Input image shape =  torch.Size([1, 64, 64])

# %%
#show the image
fig, axs = plt.subplots()
axs.imshow(sample_image.squeeze().numpy(), cmap='gray')
axs.axis('off')
axs.set_title('Sample image (Target label = {})'.format(sample_label))
plt.show()

# %%
# run the image through the model
sample_model_output = simple_model(sample_image.unsqueeze(0)).detach()

# %%
print(sample_model_output)
# Out:
# tensor([[-0.0143,  0.2440,  0.0532, -0.0569, -0.1250,  0.0421,  0.0266, -0.2194,
#          -0.0194, -0.0646, -0.0041, -0.0021, -0.0112, -0.0646, -0.1030]])

# %% [markdown]
# We have a 15-dimensional tensor as output, but how does it relate to classification?
#
# We first convert the this tensor into a probability distribution over 15 classes by applying the [Softmax](https://en.wikipedia.org/wiki/Softmax_function) operation.

# %%
sample_probability_values = torch.nn.functional.softmax(sample_model_output, dim=1)

# %%
print(sample_probability_values)
# Out:
# tensor([[0.0668, 0.0865, 0.0715, 0.0640, 0.0598, 0.0707, 0.0696, 0.0544, 0.0665,
#          0.0635, 0.0675, 0.0676, 0.0670, 0.0635, 0.0611]])

# %% [markdown]
# The prediction of the model will be the index where the probability distribution is the maximum. Convince yourself that the argmax-operation on *sample_model_values* is the same as the argmax-operation on *sample_probability_values*.
#
# **TODO 5:** Complete the ```predict_labels()``` function in ```dl_utils.py```.

# %% [markdown]
# ## 3 Loss function

# %% [markdown]
# We have written a model which takes in a tensor for an image and produces a 15 dimensional output for it. We saw in the previous section on how the output relates to the prediction and probability distribution. But how do we quantify the performance of the model, and how do we use that quantification to form an objective function which we can minimize.

# %% [markdown]
# Ideally, we would want the probability function to have value 1 for the target *sample_label* and value 0 for the remaining class indices. To penalize the deviation between the desired probability distribution and the model-predicted distrtibution, we use the KL-divergence loss or the cross-entropy loss. Please refer to [this stackexchange post](https://datascience.stackexchange.com/questions/20296/cross-entropy-loss-explanation) for a good explanation and derivation.

# %% [markdown]
# **TODO 6:** Assign a loss function to ```self.loss_criterion``` in ```simple_net.py```. Note that we have not done a softmax operation in the model's forward function and choose the [appropriate loss function](https://pytorch.org/docs/stable/nn.html#loss-functions).
#
# **TODO 7:** Complete the ```compute_loss()``` function in ```dl_utils.py``` to use the model's loss criterion and compute the loss

# %%
simple_model = SimpleNet()

# %%
print(simple_model)
# Out:
# SimpleNet(
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 40, kernel_size=(5, 5), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(40, 80, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Flatten()
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=2000, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1000, out_features=15, bias=True)
#   )
#   (loss_criterion): CrossEntropyLoss()
# )

# %%
print("Testing your model prediction: ", verify(test_predict_labels))
print("Testing your loss values: ", verify(test_compute_loss))
# Out:
# Testing your model prediction:  "Correct"
# Testing your loss values:  "Correct"

# %% [markdown]
# ## 4 Optimizer

# %% [markdown]
# ### 4.1 Manual gradient descent using Pytorch's autograd
#
# Till now, we have defined the model, and designed a loss function which is a proxy for *good* classification. We now to optimize the weights of the network so that the loss function is minimized.
#
# Pytorch is a very useful library for deep learning because a lot of tensor operations and functions support the flow of gradients. This feature is called [autograd](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html). This functionality lets use use gradient based optimization techniques like gradient descent without writing a lot of code.
#
# Let us first understand how we can access the gradients.
#
# ### Define a model and a loss function
# Suppose we have a simple objective function that looks like:
# $$ L(w) =  w^2 - 10w + 25 $$
#
# This is a convex problem, and we know that the loss $L$ is minimized for $w=5$, and we can obtain this in closed form.
#
# But let us use gradient descent to obtain the solution in this case.

# %%
import torch
from torch import tensor

def quadratic_loss(w: tensor) -> tensor:
    assert w.shape==(1,)

    # loss function
    L = torch.pow(w, 2) - 10 * w + 25
    
    return L

# %% [markdown]
# Let's compute the loss at w = 0.

# %%
w = tensor([0.0], requires_grad=True)

loss = quadratic_loss(w)

print('w={:.4f}\tLoss={:.4f}'.format(w.detach().numpy().item(), loss.detach().numpy().item()))
# Out:
# w=0.0000	Loss=25.0000

# %% [markdown]
# Now we can do a backward pass of the gradients to get the gradient of loss w.r.t w. Now we need to calculate the gradients with regard to the weights and biases using backprop. It will be very painful if we do it manually, but thankfully, in PyTorch we can have everything covered with autograd, which only needs a simple call of **.backward()** on our loss.

# %%
# perform backward on loss (we need to retain graph here otherwise Pytorch will throw it away)
loss.backward(retain_graph=True)

print(w.grad.data)

# manually zero out the gradient
w.grad.zero_()
pass
# Out:
# tensor([-10.])

# %% [markdown]
# Does this gradient match with the one you compute manually?

# %% [markdown]
# With the gradients, we can update the weights and biases using gradient descent:
# $$w_{k+1}=w_{k} - \alpha\frac{\partial L}{\partial w_k}$$
# where $w$ is the parameter we are updating, $\alpha$ is the learning rate, and $\frac{\partial L}{\partial w_k}$ is the gradient at step $k$. You can learn more about gradient descent [here](https://en.wikipedia.org/wiki/Gradient_descent) and [here](https://developers.google.com/machine-learning/crash-course/reducing-loss/gradient-descent)

# %%
# set learning rate
lr = .03

def gradientDescentStep(w: tensor, L: tensor, lr: float=1e-3) -> None:
    '''
    Take a step of the gradient descent
    '''
    
    # manually zero out the gradient
    w.grad.zero_()

    # perform backward on loss (we need to retain graph here otherwise Pytorch will throw it away)
    L.backward(retain_graph=True)
    
    with torch.no_grad():
        w -= lr * w.grad

# %% [markdown]
# Let's take one step of the gradient descent and check if the the loss value decreased

# %%
loss = quadratic_loss(w)

gradientDescentStep(w, loss, lr)

# %%
loss = quadratic_loss(w)
print('w={:.4f}\tLoss={:.4f}'.format(w.detach().numpy().item(), loss.detach().numpy().item()))
# Out:
# w=0.3000	Loss=22.0900

# %% [markdown]
# Looks like it's been optimized!
#
# Now let's run a few more updates and see where we can get!

# %%
import time


start = time.time()
for i in range(200):
    loss = quadratic_loss(w)
    if not (i+1)%10:
        print('Iteration {}: w={:.4f}\tLoss={:.4f}'.format(
            i+1, w.detach().numpy().item(), loss.detach().numpy().item()))
        
    gradientDescentStep(w, loss, lr) 
        
print('\noptimization takes %0.3f seconds'%(time.time()-start))
# Out:
# Iteration 10: w=2.3069	Loss=7.2527
# Iteration 20: w=3.5495	Loss=2.1040
# Iteration 30: w=4.2187	Loss=0.6104
# Iteration 40: w=4.5792	Loss=0.1771
# Iteration 50: w=4.7733	Loss=0.0514
# Iteration 60: w=4.8779	Loss=0.0149
# Iteration 70: w=4.9342	Loss=0.0043
# Iteration 80: w=4.9646	Loss=0.0013
# Iteration 90: w=4.9809	Loss=0.0004
# Iteration 100: w=4.9897	Loss=0.0001
# Iteration 110: w=4.9945	Loss=0.0000
# Iteration 120: w=4.9970	Loss=0.0000
# Iteration 130: w=4.9984	Loss=0.0000
# Iteration 140: w=4.9991	Loss=0.0000
# Iteration 150: w=4.9995	Loss=0.0000
# Iteration 160: w=4.9997	Loss=0.0000
# Iteration 170: w=4.9999	Loss=0.0000
# Iteration 180: w=4.9999	Loss=0.0000
# Iteration 190: w=5.0000	Loss=-0.0000
# Iteration 200: w=5.0000	Loss=0.0000
#
# optimization takes 0.031 seconds

# %% [markdown]
# Seems that it's doing a great job training our model! The loss now has decreased significantly to a pretty small value.

# %% [markdown]
# ### 4.2 Optimization using Pytorch's gradient descent optimizer
#
# Now let's see how we can simplify this using the `torch.optim` package from PyTorch. You can see that using optimizer from `torch.optim` package can achieve the same results with a lot less code from our side. Also, there are many features available over the vanilla gradient descent. Let's use the Stochastic Gradient Descent (SGD) optimizer available in Pytorch.

# %%
from torch.optim import SGD

# define parameters we want to optimize
w = tensor([0.0], requires_grad=True)

optimizer = SGD([w], lr=lr)

start = time.time()
for i in range(200):
    loss = quadratic_loss(w)   
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if not (i+1)%10:
        print('Iteration {}: w={:.4f}\tLoss={:.4f}'.format(
            i+1, w.detach().numpy().item(), loss.detach().numpy().item()))
        
print('\noptimization takes %0.3f seconds'%(time.time()-start))
# Out:
# Iteration 10: w=2.3069	Loss=8.2081
# Iteration 20: w=3.5495	Loss=2.3812
# Iteration 30: w=4.2187	Loss=0.6908
# Iteration 40: w=4.5792	Loss=0.2004
# Iteration 50: w=4.7733	Loss=0.0581
# Iteration 60: w=4.8779	Loss=0.0169
# Iteration 70: w=4.9342	Loss=0.0049
# Iteration 80: w=4.9646	Loss=0.0014
# Iteration 90: w=4.9809	Loss=0.0004
# Iteration 100: w=4.9897	Loss=0.0001
# Iteration 110: w=4.9945	Loss=0.0000
# Iteration 120: w=4.9970	Loss=0.0000
# Iteration 130: w=4.9984	Loss=0.0000
# Iteration 140: w=4.9991	Loss=-0.0000
# Iteration 150: w=4.9995	Loss=0.0000
# Iteration 160: w=4.9997	Loss=0.0000
# Iteration 170: w=4.9999	Loss=0.0000
# Iteration 180: w=4.9999	Loss=0.0000
# Iteration 190: w=5.0000	Loss=0.0000
# Iteration 200: w=5.0000	Loss=0.0000
#
# optimization takes 0.030 seconds

# %% [markdown]
# ### 4.3 Setting up the optimizer for SimpleNet

# %% [markdown]
# **TODO 8:** **initialize the following cell with proper values for learning rate and weight decay**
#
# **Note:** There is nothing to do in this TODO for the first pass. You'll train the model with these values and it will be bad. Then you can come back here and tune the parameters.

# %%
# TODO: add a decent initial setting and tune from there
optimizer_config = {
  "optimizer_type": "sgd",
  "lr": 5e-3,
  "weight_decay": 3e-4
}

# %% [markdown]
# We will now set up a utility function to define an optimizer on the loss for a model.
#
# **TODO 9:** complete the ```get_optimizer()``` function in ```optimizer.py```. The helper function accepts three basic configurations as defined below. Any other configuration is optional. *SGD* optimizer type should be supported, anything else is optional.

# %%
optimizer = get_optimizer(simple_model, optimizer_config)

# %% [markdown]
# ## 5 Training SimpleNet

# %% [markdown]
# We have completed all the components required to train the first model for this course. Let's pass in the model architecture, optimizer, transforms for both the training and testing datasets into the trainer, and proceed to the next cell to train it. If you have implemented everything correctly, you should be seeing a decreasing loss value.
#
# **Note** in this project, we will be using the test set as the validation set (i.e. using it to guide our decisions about models and hyperparamters while training. In actual practise, you would not interact with the test set until reporting the final results.
#
# **Note** that your CPU should be sufficient to handle the training process for all networks in this project, and the following training cells will take less than 5 minutes; you may also want to decrease the value for `num_epochs` and quickly experiment with your parameters. The default value of **30** is good enough to get you around the threshold for Part 1, and you are free to increase it a bit and adjust other parameters in this part.

# %%
# re-init the model so that the weights are all random
simple_model = SimpleNet()
optimizer = get_optimizer(simple_model, optimizer_config)

trainer = Trainer(data_dir=data_base_path, 
                  model = simple_model,
                  optimizer = optimizer,
                  model_dir = os.path.join(model_base_path, 'simple_net'),
                  train_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  test_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  batch_size = 15,
                  load_from_disk = False,
                  cuda = is_cuda
                 )

# %%
import time
simple_net_start = time.time()
trainer.train(num_epochs=30)
simple_net_end = time.time()
print("The training time taken for simple net is {:.9f}".format(simple_net_end-simple_net_start))
# Out:
# Epoch:0, Training Loss:2.7076, Validation Loss:2.7123
# Epoch:1, Training Loss:2.5854, Validation Loss:2.6561
# Epoch:2, Training Loss:2.4166, Validation Loss:2.4994
# Epoch:3, Training Loss:2.2869, Validation Loss:2.3642
# Epoch:4, Training Loss:2.1033, Validation Loss:2.2043
# Epoch:5, Training Loss:1.9513, Validation Loss:2.0788
# Epoch:6, Training Loss:1.8280, Validation Loss:1.9282
# Epoch:7, Training Loss:1.7360, Validation Loss:1.9461
# Epoch:8, Training Loss:1.5668, Validation Loss:1.7842
# Epoch:9, Training Loss:1.4882, Validation Loss:1.7728
# Epoch:10, Training Loss:1.4375, Validation Loss:1.6995
# Epoch:11, Training Loss:1.3332, Validation Loss:1.6779
# Epoch:12, Training Loss:1.3516, Validation Loss:1.7151
# Epoch:13, Training Loss:1.2558, Validation Loss:1.6780
# Epoch:14, Training Loss:1.2349, Validation Loss:1.7315
# Epoch:15, Training Loss:1.0919, Validation Loss:1.5680
# Epoch:16, Training Loss:1.0452, Validation Loss:1.5763
# Epoch:17, Training Loss:0.9486, Validation Loss:1.5455
# Epoch:18, Training Loss:0.9486, Validation Loss:1.5888
# Epoch:19, Training Loss:1.0034, Validation Loss:1.7012
# Epoch:20, Training Loss:0.9007, Validation Loss:1.6193
# Epoch:21, Training Loss:0.7450, Validation Loss:1.5555
# Epoch:22, Training Loss:0.7470, Validation Loss:1.6215
# Epoch:23, Training Loss:0.6917, Validation Loss:1.7261
# Epoch:24, Training Loss:0.5665, Validation Loss:1.5273
# Epoch:25, Training Loss:0.5364, Validation Loss:1.6568
# Epoch:26, Training Loss:0.5969, Validation Loss:1.7502
# Epoch:27, Training Loss:0.4331, Validation Loss:1.6899
# Epoch:28, Training Loss:0.4021, Validation Loss:1.7481
# Epoch:29, Training Loss:0.3755, Validation Loss:1.8544
# Epoch:30, Training Loss:0.3498, Validation Loss:1.8621
# The training time taken for simple net is 271.207928658

# %% [markdown]
# Now let's have your model predict on some examples and see how well it performs qualitatively. You should try the following cell multiple times to understand whats happening.

# %%
# visualize train split
print("Examples from train split:")
visualize(simple_model, 'train', get_fundamental_transforms(inp_size, dataset_mean, dataset_std), data_base_path)
# Out:
# Examples from train split:

# %%
# visualize test split
print("Examples from test split:")
visualize(simple_model, 'test', get_fundamental_transforms(inp_size, dataset_mean, dataset_std), data_base_path)
# Out:
# Examples from test split:

# %%
trainer.plot_loss_history()
trainer.plot_accuracy()

# %%
train_accuracy = trainer.train_accuracy_history[-1]
validation_accuracy = trainer.validation_accuracy_history[-1]
print('Train Accuracy = {:.4f}; Validation Accuracy = {:.4f}'.format(train_accuracy, validation_accuracy))
# Out:
# Train Accuracy = 0.8965; Validation Accuracy = 0.4953

# %%
print('Testing simple net weights saved: ', verify(test_simple_net_checkpoint))
# Out:
# Testing simple net weights saved:  "Correct"

# %% [markdown]
# After you have finished the training process, now plot out the loss and accuracy history. You can also check out the final accuracy for both training and validation data. Copy the accuracy plots and values onto the report, and answer the questions there.
#
# **TODO 10:** Obtain a **45%** validation accuracy to receive full credits for Part 1. You can go back to TODO 8 first to tune your paramters for optimization using the following tips:
#
# **Tips**:
# 1. If the loss decreases very slowly, try increasing the value of the lr (learning rate).
# 2. Initially keep the value of weight decay (L2-regulization) very low.
# 3. Try to first adjust lr in multiples of 3 initially. When you are close to reasonable performance, do a more granular adjustment.
# 4. If you want to increase the validation accuracy by a little bit, try increasing the weight_decay to prevent overfitting. Do not use tricks from Section 6 just yet.
#
# If you still need to tweak the model architecture, you are free to do so. But remember complex models will require more time to train, and TAs could achieve ~50% accuracy with the described model.

# %% [markdown]
# ## 6 Solving overfitting
# We have obtained a 45% accuracy on the validation data with a simple model; Feeling even better for the training accuracy right? More than 90% (if you have implemented everything correctly). But should you?
#
# Our final accuracies for training and validation data differ a lot from each other, which indicates that the model we have defined **fits too well with the training data, but is unable to generalize well on data it has not trained on**: this is often regarded as **overfitting**. In this section we are going to apply 2 techniques to tackle with it: adjusting both data and model.
#
# ### 6.1 Jitter, Random Flip, and Normalization
# One common technique to increase the "variability" of the data is to **augment** it. Firstly, we don't have a huge amount of data, so let's "jitter" it; secondly, when you mirror an image of a **kitchen**, you can tell that the mirrored image is still a kitchen.
#
# **TODO 11:** finish the `get_data_augmentation_transforms()` function in `data_transforms.py`: you should first copy your existing fundamental transform implementation into this function, and then insert a couple of other transforms which help you do the above adjustment
#
# You are free to experiment with different kinds of augmentation techniques by adding new techniques or replacing existing techniques

# %%
inp_size = (64,64)

# %% [markdown]
# ### 6.2 Dropout
# "Dropout" is a technique commonly used to regularize the network. It randomly turns off the connection between neurons inside the network and prevent the network from relying too much on a specific neuron.
#
# **TODO 12:** finish the `simple_net_dropout.py` with your previous SimpleNet model, plus the dropout layer.

# %%
print("Testing your SimpleNetDropout architecture: ", verify(test_simple_net_dropout))
# Out:
# Testing your SimpleNetDropout architecture:  "Correct"

# %%
simple_model_dropout = SimpleNetDropout()
print(simple_model_dropout)
# Out:
# SimpleNetDropout(
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 40, kernel_size=(5, 5), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(40, 80, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Flatten()
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=2000, out_features=1000, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#     (3): Linear(in_features=1000, out_features=15, bias=True)
#   )
#   (loss_criterion): CrossEntropyLoss()
# )

# %% [markdown]
# Similar to the previous part, **initialize the following cell with proper values for learning rate and weight decay**.

# %%
# TODO: add a decent initial setting and tune from there
optimizer_config = {
  "optimizer_type": "sgd",
  "lr": 5e-3,
  "weight_decay": 3e-4
}

# %%
simple_model_dropout = SimpleNetDropout()
optimizer = get_optimizer(simple_model_dropout, optimizer_config)

trainer = Trainer(data_dir=data_base_path, 
                  model = simple_model_dropout,
                  optimizer = optimizer,
                  model_dir = os.path.join(model_base_path, 'simple_net_dropout'),
                  train_data_transforms = get_data_augmentation_transforms(inp_size, dataset_mean, dataset_std),
                  test_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  batch_size = 15,
                  load_from_disk = False,
                  cuda = is_cuda
                 )

# %% [markdown]
# The following cell will take longer than Part 1, as now we have more data (and more variability), and the model is slightly more complicated than before as well; however, it should finish within 10~15 minutes anyway, and the default `num_epochs` is also good enough as a starting point for you to pass this part.

# %%
trainer.train(num_epochs=30)
# Out:
# Epoch:0, Training Loss:2.7134, Validation Loss:2.7103
# Epoch:1, Training Loss:2.5979, Validation Loss:2.6718
# Epoch:2, Training Loss:2.4509, Validation Loss:2.5391
# Epoch:3, Training Loss:2.3315, Validation Loss:2.4147
# Epoch:4, Training Loss:2.2186, Validation Loss:2.3206
# Epoch:5, Training Loss:2.0554, Validation Loss:2.1613
# Epoch:6, Training Loss:1.9322, Validation Loss:2.0622
# Epoch:7, Training Loss:1.8207, Validation Loss:1.9729
# Epoch:8, Training Loss:1.7361, Validation Loss:1.9289
# Epoch:9, Training Loss:1.6213, Validation Loss:1.7858
# Epoch:10, Training Loss:1.5433, Validation Loss:1.7808
# Epoch:11, Training Loss:1.5459, Validation Loss:1.7795
# Epoch:12, Training Loss:1.4142, Validation Loss:1.6886
# Epoch:13, Training Loss:1.3756, Validation Loss:1.6610
# Epoch:14, Training Loss:1.3106, Validation Loss:1.6489
# Epoch:15, Training Loss:1.3287, Validation Loss:1.6754
# Epoch:16, Training Loss:1.2770, Validation Loss:1.6244
# Epoch:17, Training Loss:1.1863, Validation Loss:1.5881
# Epoch:18, Training Loss:1.1566, Validation Loss:1.6182
# Epoch:19, Training Loss:1.0918, Validation Loss:1.5573
# Epoch:20, Training Loss:1.0644, Validation Loss:1.5842
# Epoch:21, Training Loss:1.0765, Validation Loss:1.6542
# Epoch:22, Training Loss:0.9577, Validation Loss:1.5157
# Epoch:23, Training Loss:0.9649, Validation Loss:1.5817
# Epoch:24, Training Loss:0.8869, Validation Loss:1.5545
# Epoch:25, Training Loss:0.7964, Validation Loss:1.5038
# Epoch:26, Training Loss:0.7542, Validation Loss:1.5100
# Epoch:27, Training Loss:0.7682, Validation Loss:1.5637
# Epoch:28, Training Loss:0.6662, Validation Loss:1.5351
# Epoch:29, Training Loss:0.6465, Validation Loss:1.4904
# Epoch:30, Training Loss:0.6521, Validation Loss:1.4864

# %% [markdown]
# Now let's have your model predict on some examples and see how well it performs qualitatively.

# %%
# # visualize train split
print("Examples from train split:")
visualize(simple_model_dropout, 'train', get_fundamental_transforms(inp_size, dataset_mean, dataset_std))
# Out:
# Examples from train split:

# %%
# # visualize test split
print("Examples from test split:")
visualize(simple_model_dropout, 'test', get_fundamental_transforms(inp_size, dataset_mean, dataset_std))
# Out:
# Examples from test split:

# %%
trainer.plot_loss_history()
trainer.plot_accuracy()

# %%
train_accuracy = trainer.train_accuracy_history[-1]
validation_accuracy = trainer.validation_accuracy_history[-1]
print('Train Accuracy = {:.4f}; Validation Accuracy = {:.4f}'.format(train_accuracy, validation_accuracy))
# Out:
# Train Accuracy = 0.8151; Validation Accuracy = 0.5233

# %% [markdown]
# Similar to the previous part, now plot out the loss and accuracy history. Also copy the plots onto the report, and answer the questions accordingly.
#
# **TODO 13:** Achieve **52%** validation accuracy for full credits for this part.

# %% [markdown]
# ## 7 Pretrained AlexNet
# You can see that after the above adjustment, our model performance increases in terms of testing accuracy. Although the training accuracy drops, now it's closer to the testing values and that's more natural in terms of performance. But we are not satisfied with the final performance yet. Our model, in the end, is still a 2-layer SimpleNet and it might be capable of capturing some features, but could be improved a lot if we go **deeper**. In this part we are going to see the power of a famous model: AlexNet.

# %%
inp_size = (224, 224)

# %% [markdown]
# PyTorch has provided us with pre-trained models like AlexNet, so what you want to do is to load the model first, and then adjust some of the layers such that it fits with our own dataset, instead of outputing scores to 1000 classes from the original AlexNet model.
#
# There are many reasons for using pre-trained weights instead of training AlexNet from scratch:
# 1. We have a really small dataset. Alexnet has millions of parameters and will definitely overfit. The pre-trained alexnet will have access to millions of training images.
# 2. We save a lot of computation.
#
# **TODO 14:** Switch to `my_alexnet.py`, and copy the network architecture and weights of all but the last fc layers from the pretrained network.
#
# After you have defined the correct architecture of the model, make some tweaks to the existing layers: **freeze** the **convolutional** layers and first 2 **linear** layers so we don't update the weights of them. More instructions are in the docstring.
#
# Note that you are allowed to add more layers/unfreeze more layers if you see fit.

# %%
print("Testing your AlexNet architecture: ", verify(test_my_alexnet))
# Out:
# Testing your AlexNet architecture:  "Correct"

# %%
my_alexnet = MyAlexNet()
print(my_alexnet)
# Out:
# MyAlexNet(
#   (cnn_layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (flatten): Flatten()
#   )
#   (fc_layers): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=15, bias=True)
#   )
#   (loss_criterion): CrossEntropyLoss()
# )

# %%
# TODO: add a decent initial setting and tune from there
optimizer_config = {
  "optimizer_type": "sgd",
  "lr": 5e-3,
  "weight_decay": 3e-4
}

# %%
my_alexnet = MyAlexNet()
optimizer = get_optimizer(my_alexnet, optimizer_config)

trainer = Trainer(data_dir=data_base_path, 
                  model = my_alexnet,
                  optimizer = optimizer,
                  model_dir = os.path.join(model_base_path, 'alexnet'),
                  train_data_transforms = get_data_augmentation_transforms(inp_size, dataset_mean, dataset_std),
                  test_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  batch_size = 15,
                  load_from_disk = False,
                  cuda = is_cuda
                 )

# %% [markdown]
# The following training cell will take roughly 20 minutes or slightly more using CPU (but possibly under 5 minute using GPU depending on the batch size; the TAs got it within 3 minutes on a GTX1060).

# %%
trainer.train(num_epochs=5)
# Out:
# Epoch:0, Training Loss:2.7653, Validation Loss:2.7496
# Epoch:1, Training Loss:0.3726, Validation Loss:0.5306
# Epoch:2, Training Loss:0.2542, Validation Loss:0.4135
# Epoch:3, Training Loss:0.2148, Validation Loss:0.3865
# Epoch:4, Training Loss:0.1935, Validation Loss:0.3542
# Epoch:5, Training Loss:0.1614, Validation Loss:0.3483

# %% [markdown]
# Now let's have your model predict on some examples and see how well it performs qualitatively.

# %%
# # visualize train split
print("Examples from train split:")
visualize(my_alexnet, 'train', get_fundamental_transforms(inp_size, dataset_mean, dataset_std))
# Out:
# Examples from train split:

# %%
# # visualize test split
print("Examples from test split:")
visualize(my_alexnet, 'test', get_fundamental_transforms(inp_size, dataset_mean, dataset_std))
# Out:
# Examples from test split:

# %%
trainer.plot_loss_history()
trainer.plot_accuracy()

# %%
train_accuracy = trainer.train_accuracy_history[-1]
validation_accuracy = trainer.validation_accuracy_history[-1]
print('Train Accuracy = {:.4f}; Validation Accuracy = {:.4f}'.format(train_accuracy, validation_accuracy))
# Out:
# Train Accuracy = 0.9548; Validation Accuracy = 0.8760

# %%
# !zip -r /content/file.zip /content/
# Out:
# updating: content/ (stored 0%)
# updating: content/.config/ (stored 0%)
# updating: content/.config/active_config (stored 0%)
# updating: content/.config/config_sentinel (stored 0%)
# updating: content/.config/.last_opt_in_prompt.yaml (stored 0%)
# updating: content/.config/.last_survey_prompt.yaml (stored 0%)
# updating: content/.config/.last_update_check.json (deflated 23%)
# updating: content/.config/gce (stored 0%)
# updating: content/.config/logs/ (stored 0%)
# updating: content/.config/logs/2020.10.05/ (stored 0%)
# updating: content/.config/logs/2020.10.05/16.30.42.685964.log (deflated 54%)
# updating: content/.config/logs/2020.10.05/16.31.17.532147.log (deflated 55%)
# updating: content/.config/logs/2020.10.05/16.30.57.046091.log (deflated 87%)
# updating: content/.config/logs/2020.10.05/16.31.02.426408.log (deflated 54%)
# updating: content/.config/logs/2020.10.05/16.30.24.482958.log (deflated 92%)
# updating: content/.config/logs/2020.10.05/16.31.18.233006.log (deflated 54%)
# updating: content/.config/configurations/ (stored 0%)
# updating: content/.config/configurations/config_default (deflated 15%)
# updating: content/.config/.metricsUUID (stored 0%)
# updating: content/simplenet.jpg (deflated 25%)
# updating: content/rwang646.pdf (deflated 19%)
# updating: content/proj2_env_mac.yml (deflated 35%)
# updating: content/.zip_dir_list.yml (deflated 32%)
# updating: content/proj2_colab.zip (stored 0%)
# updating: content/proj2_env_win.yml (deflated 33%)
# updating: content/model_checkpoints/ (stored 0%)
# updating: content/model_checkpoints/simple_net_ablation/ (stored 0%)
# updating: content/model_checkpoints/simple_net_ablation/empty.md (stored 0%)
# updating: content/model_checkpoints/simple_net_dropout/ (stored 0%)
# updating: content/model_checkpoints/simple_net_dropout/checkpoint.pt (deflated 8%)
# updating: content/model_checkpoints/simple_net_dropout/empty.md (stored 0%)
# updating: content/model_checkpoints/quantized_alexnet/ (stored 0%)
# updating: content/model_checkpoints/quantized_alexnet/empty.md (stored 0%)
# updating: content/model_checkpoints/simple_net/ (stored 0%)
# updating: content/model_checkpoints/simple_net/checkpoint.pt (deflated 8%)
# updating: content/model_checkpoints/simple_net/empty.md (stored 0%)
# updating: content/model_checkpoints/alexnet/ (stored 0%)
# updating: content/model_checkpoints/alexnet/checkpoint.pt (deflated 7%)
# updating: content/model_checkpoints/alexnet/empty.md (stored 0%)
# updating: content/proj2_env_linux.yml (deflated 35%)
# updating: content/.pytest_cache/ (stored 0%)
# updating: content/.pytest_cache/.gitignore (stored 0%)
# updating: content/.pytest_cache/v/ (stored 0%)
# updating: content/.pytest_cache/v/cache/ (stored 0%)
# updating: content/.pytest_cache/v/cache/nodeids (deflated 79%)
# updating: content/.pytest_cache/v/cache/stepwise (stored 0%)
# updating: content/.pytest_cache/README.md (deflated 32%)
# updating: content/.pytest_cache/CACHEDIR.TAG (deflated 24%)
# updating: content/README.md (stored 0%)
# updating: content/data/ (stored 0%)
# updating: content/data/train/ (stored 0%)
# updating: content/data/train/insidecity/ (stored 0%)
# updating: content/data/train/insidecity/image_0252.jpg (deflated 1%)
# updating: content/data/train/insidecity/image_0023.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0001.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0007.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0270.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0266.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0210.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0056.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0201.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0240.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0239.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0063.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0207.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0053.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0307.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0049.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0065.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0137.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0140.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0228.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0043.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0297.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0291.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0127.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0040.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0189.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0277.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0196.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0091.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0188.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0077.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0038.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0190.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0051.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0280.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0022.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0187.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0220.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0084.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0241.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0213.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0010.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0286.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0117.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0222.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0248.jpg (deflated 1%)
# updating: content/data/train/insidecity/image_0215.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0133.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0082.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0089.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0069.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0168.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0194.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0061.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0149.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0129.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0198.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0204.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0024.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0054.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0104.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0163.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0073.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0263.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0033.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0249.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0158.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0093.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0176.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0267.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0160.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0206.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0224.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0110.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0178.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0020.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0059.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0092.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0122.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0078.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0191.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0062.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0044.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0256.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0276.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0057.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0146.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0126.jpg (deflated 2%)
# updating: content/data/train/insidecity/image_0173.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0170.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0087.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0048.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0225.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0269.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0029.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0284.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0246.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0300.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0016.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0217.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0109.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0088.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0171.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0229.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0298.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0184.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0097.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0031.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0287.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0066.jpg (deflated 1%)
# updating: content/data/train/insidecity/image_0193.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0275.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0165.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0219.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0060.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0015.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0035.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0153.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0125.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0250.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0042.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0288.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0197.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0132.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0268.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0150.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0050.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0214.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0098.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0100.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0283.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0019.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0041.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0175.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0299.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0123.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0304.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0067.jpg (deflated 1%)
# updating: content/data/train/insidecity/image_0271.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0306.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0003.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0131.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0128.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0233.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0107.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0208.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0145.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0011.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0008.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0192.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0075.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0103.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0124.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0017.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0218.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0021.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0119.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0071.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0296.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0134.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0142.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0105.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0094.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0139.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0039.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0273.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0068.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0013.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0141.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0079.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0202.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0025.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0223.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0237.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0012.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0111.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0289.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0162.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0303.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0243.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0251.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0282.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0085.jpg (deflated 1%)
# updating: content/data/train/insidecity/image_0096.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0285.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0004.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0272.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0301.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0095.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0002.jpg (deflated 2%)
# updating: content/data/train/insidecity/image_0161.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0052.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0179.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0166.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0186.jpg (deflated 1%)
# updating: content/data/train/insidecity/image_0195.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0037.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0205.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0238.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0055.jpg (deflated 0%)
# updating: content/data/train/insidecity/image_0118.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0006.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0130.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0235.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0209.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0231.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0292.jpg (stored 0%)
# updating: content/data/train/insidecity/image_0200.jpg (stored 0%)
# updating: content/data/train/office/ (stored 0%)
# updating: content/data/train/office/image_0034.jpg (deflated 0%)
# updating: content/data/train/office/image_0023.jpg (stored 0%)
# updating: content/data/train/office/image_0001.jpg (stored 0%)
# updating: content/data/train/office/image_0007.jpg (stored 0%)
# updating: content/data/train/office/image_0148.jpg (stored 0%)
# updating: content/data/train/office/image_0114.jpg (stored 0%)
# updating: content/data/train/office/image_0108.jpg (stored 0%)
# updating: content/data/train/office/image_0063.jpg (stored 0%)
# updating: content/data/train/office/image_0207.jpg (stored 0%)
# updating: content/data/train/office/image_0065.jpg (stored 0%)
# updating: content/data/train/office/image_0140.jpg (stored 0%)
# updating: content/data/train/office/image_0081.jpg (stored 0%)
# updating: content/data/train/office/image_0157.jpg (stored 0%)
# updating: content/data/train/office/image_0043.jpg (stored 0%)
# updating: content/data/train/office/image_0127.jpg (stored 0%)
# updating: content/data/train/office/image_0040.jpg (stored 0%)
# updating: content/data/train/office/image_0072.jpg (stored 0%)
# updating: content/data/train/office/image_0196.jpg (stored 0%)
# updating: content/data/train/office/image_0091.jpg (stored 0%)
# updating: content/data/train/office/image_0188.jpg (deflated 0%)
# updating: content/data/train/office/image_0077.jpg (stored 0%)
# updating: content/data/train/office/image_0038.jpg (stored 0%)
# updating: content/data/train/office/image_0164.jpg (stored 0%)
# updating: content/data/train/office/image_0185.jpg (stored 0%)
# updating: content/data/train/office/image_0022.jpg (stored 0%)
# updating: content/data/train/office/image_0138.jpg (stored 0%)
# updating: content/data/train/office/image_0084.jpg (stored 0%)
# updating: content/data/train/office/image_0064.jpg (stored 0%)
# updating: content/data/train/office/image_0213.jpg (stored 0%)
# updating: content/data/train/office/image_0010.jpg (stored 0%)
# updating: content/data/train/office/image_0117.jpg (stored 0%)
# updating: content/data/train/office/image_0083.jpg (stored 0%)
# updating: content/data/train/office/image_0089.jpg (stored 0%)
# updating: content/data/train/office/image_0168.jpg (stored 0%)
# updating: content/data/train/office/image_0204.jpg (stored 0%)
# updating: content/data/train/office/image_0024.jpg (stored 0%)
# updating: content/data/train/office/image_0026.jpg (stored 0%)
# updating: content/data/train/office/image_0158.jpg (stored 0%)
# updating: content/data/train/office/image_0112.jpg (stored 0%)
# updating: content/data/train/office/image_0176.jpg (stored 0%)
# updating: content/data/train/office/image_0120.jpg (stored 0%)
# updating: content/data/train/office/image_0183.jpg (stored 0%)
# updating: content/data/train/office/image_0110.jpg (deflated 0%)
# updating: content/data/train/office/image_0020.jpg (stored 0%)
# updating: content/data/train/office/image_0059.jpg (stored 0%)
# updating: content/data/train/office/image_0092.jpg (stored 0%)
# updating: content/data/train/office/image_0191.jpg (stored 0%)
# updating: content/data/train/office/image_0062.jpg (stored 0%)
# updating: content/data/train/office/image_0044.jpg (stored 0%)
# updating: content/data/train/office/image_0106.jpg (stored 0%)
# updating: content/data/train/office/image_0057.jpg (stored 0%)
# updating: content/data/train/office/image_0146.jpg (stored 0%)
# updating: content/data/train/office/image_0126.jpg (stored 0%)
# updating: content/data/train/office/image_0048.jpg (stored 0%)
# updating: content/data/train/office/image_0029.jpg (stored 0%)
# updating: content/data/train/office/image_0088.jpg (stored 0%)
# updating: content/data/train/office/image_0155.jpg (stored 0%)
# updating: content/data/train/office/image_0193.jpg (stored 0%)
# updating: content/data/train/office/image_0005.jpg (deflated 1%)
# updating: content/data/train/office/image_0080.jpg (stored 0%)
# updating: content/data/train/office/image_0060.jpg (stored 0%)
# updating: content/data/train/office/image_0015.jpg (stored 0%)
# updating: content/data/train/office/image_0102.jpg (deflated 0%)
# updating: content/data/train/office/image_0032.jpg (deflated 0%)
# updating: content/data/train/office/image_0150.jpg (stored 0%)
# updating: content/data/train/office/image_0116.jpg (stored 0%)
# updating: content/data/train/office/image_0050.jpg (stored 0%)
# updating: content/data/train/office/image_0174.jpg (stored 0%)
# updating: content/data/train/office/image_0214.jpg (stored 0%)
# updating: content/data/train/office/image_0100.jpg (deflated 1%)
# updating: content/data/train/office/image_0047.jpg (stored 0%)
# updating: content/data/train/office/image_0019.jpg (stored 0%)
# updating: content/data/train/office/image_0159.jpg (stored 0%)
# updating: content/data/train/office/image_0123.jpg (stored 0%)
# updating: content/data/train/office/image_0067.jpg (stored 0%)
# updating: content/data/train/office/image_0144.jpg (stored 0%)
# updating: content/data/train/office/image_0003.jpg (deflated 0%)
# updating: content/data/train/office/image_0143.jpg (stored 0%)
# updating: content/data/train/office/image_0131.jpg (deflated 0%)
# updating: content/data/train/office/image_0121.jpg (deflated 0%)
# updating: content/data/train/office/image_0107.jpg (stored 0%)
# updating: content/data/train/office/image_0208.jpg (deflated 0%)
# updating: content/data/train/office/image_0011.jpg (stored 0%)
# updating: content/data/train/office/image_0192.jpg (stored 0%)
# updating: content/data/train/office/image_0075.jpg (stored 0%)
# updating: content/data/train/office/image_0103.jpg (stored 0%)
# updating: content/data/train/office/image_0124.jpg (stored 0%)
# updating: content/data/train/office/image_0119.jpg (stored 0%)
# updating: content/data/train/office/image_0071.jpg (stored 0%)
# updating: content/data/train/office/image_0134.jpg (stored 0%)
# updating: content/data/train/office/image_0142.jpg (stored 0%)
# updating: content/data/train/office/image_0135.jpg (stored 0%)
# updating: content/data/train/office/image_0027.jpg (stored 0%)
# updating: content/data/train/office/image_0079.jpg (stored 0%)
# updating: content/data/train/office/image_0074.jpg (stored 0%)
# updating: content/data/train/office/image_0009.jpg (stored 0%)
# updating: content/data/train/office/image_0199.jpg (stored 0%)
# updating: content/data/train/office/image_0012.jpg (stored 0%)
# updating: content/data/train/office/image_0058.jpg (stored 0%)
# updating: content/data/train/office/image_0096.jpg (stored 0%)
# updating: content/data/train/office/image_0004.jpg (deflated 0%)
# updating: content/data/train/office/image_0181.jpg (stored 0%)
# updating: content/data/train/office/image_0169.jpg (stored 0%)
# updating: content/data/train/office/image_0180.jpg (stored 0%)
# updating: content/data/train/office/image_0147.jpg (deflated 1%)
# updating: content/data/train/office/image_0179.jpg (stored 0%)
# updating: content/data/train/office/image_0186.jpg (stored 0%)
# updating: content/data/train/office/image_0037.jpg (deflated 0%)
# updating: content/data/train/office/image_0205.jpg (stored 0%)
# updating: content/data/train/office/image_0055.jpg (stored 0%)
# updating: content/data/train/office/image_0118.jpg (stored 0%)
# updating: content/data/train/office/image_0006.jpg (stored 0%)
# updating: content/data/train/office/image_0130.jpg (deflated 0%)
# updating: content/data/train/office/image_0203.jpg (stored 0%)
# updating: content/data/train/office/image_0200.jpg (stored 0%)
# updating: content/data/train/highway/ (stored 0%)
# updating: content/data/train/highway/image_0230.jpg (deflated 0%)
# updating: content/data/train/highway/image_0252.jpg (stored 0%)
# updating: content/data/train/highway/image_0034.jpg (stored 0%)
# updating: content/data/train/highway/image_0001.jpg (stored 0%)
# updating: content/data/train/highway/image_0007.jpg (deflated 2%)
# updating: content/data/train/highway/image_0086.jpg (deflated 2%)
# updating: content/data/train/highway/image_0210.jpg (stored 0%)
# updating: content/data/train/highway/image_0056.jpg (deflated 4%)
# updating: content/data/train/highway/image_0201.jpg (deflated 0%)
# updating: content/data/train/highway/image_0240.jpg (stored 0%)
# updating: content/data/train/highway/image_0108.jpg (deflated 1%)
# updating: content/data/train/highway/image_0063.jpg (deflated 2%)
# updating: content/data/train/highway/image_0090.jpg (deflated 3%)
# updating: content/data/train/highway/image_0053.jpg (deflated 3%)
# updating: content/data/train/highway/image_0257.jpg (stored 0%)
# updating: content/data/train/highway/image_0137.jpg (deflated 2%)
# updating: content/data/train/highway/image_0140.jpg (deflated 0%)
# updating: content/data/train/highway/image_0157.jpg (deflated 0%)
# updating: content/data/train/highway/image_0245.jpg (deflated 0%)
# updating: content/data/train/highway/image_0040.jpg (deflated 5%)
# updating: content/data/train/highway/image_0196.jpg (deflated 0%)
# updating: content/data/train/highway/image_0091.jpg (deflated 1%)
# updating: content/data/train/highway/image_0136.jpg (deflated 1%)
# updating: content/data/train/highway/image_0190.jpg (deflated 1%)
# updating: content/data/train/highway/image_0164.jpg (deflated 1%)
# updating: content/data/train/highway/image_0051.jpg (deflated 5%)
# updating: content/data/train/highway/image_0185.jpg (stored 0%)
# updating: content/data/train/highway/image_0022.jpg (stored 0%)
# updating: content/data/train/highway/image_0172.jpg (stored 0%)
# updating: content/data/train/highway/image_0220.jpg (stored 0%)
# updating: content/data/train/highway/image_0084.jpg (deflated 2%)
# updating: content/data/train/highway/image_0030.jpg (stored 0%)
# updating: content/data/train/highway/image_0255.jpg (deflated 0%)
# updating: content/data/train/highway/image_0241.jpg (stored 0%)
# updating: content/data/train/highway/image_0213.jpg (stored 0%)
# updating: content/data/train/highway/image_0215.jpg (stored 0%)
# updating: content/data/train/highway/image_0133.jpg (stored 0%)
# updating: content/data/train/highway/image_0082.jpg (deflated 7%)
# updating: content/data/train/highway/image_0089.jpg (deflated 5%)
# updating: content/data/train/highway/image_0168.jpg (deflated 0%)
# updating: content/data/train/highway/image_0194.jpg (stored 0%)
# updating: content/data/train/highway/image_0061.jpg (deflated 2%)
# updating: content/data/train/highway/image_0149.jpg (stored 0%)
# updating: content/data/train/highway/image_0024.jpg (stored 0%)
# updating: content/data/train/highway/image_0104.jpg (deflated 1%)
# updating: content/data/train/highway/image_0212.jpg (stored 0%)
# updating: content/data/train/highway/image_0226.jpg (stored 0%)
# updating: content/data/train/highway/image_0249.jpg (deflated 0%)
# updating: content/data/train/highway/image_0026.jpg (stored 0%)
# updating: content/data/train/highway/image_0253.jpg (stored 0%)
# updating: content/data/train/highway/image_0158.jpg (deflated 2%)
# updating: content/data/train/highway/image_0093.jpg (deflated 1%)
# updating: content/data/train/highway/image_0176.jpg (stored 0%)
# updating: content/data/train/highway/image_0206.jpg (stored 0%)
# updating: content/data/train/highway/image_0221.jpg (stored 0%)
# updating: content/data/train/highway/image_0110.jpg (stored 0%)
# updating: content/data/train/highway/image_0178.jpg (stored 0%)
# updating: content/data/train/highway/image_0020.jpg (deflated 2%)
# updating: content/data/train/highway/image_0046.jpg (deflated 3%)
# updating: content/data/train/highway/image_0092.jpg (deflated 2%)
# updating: content/data/train/highway/image_0078.jpg (deflated 1%)
# updating: content/data/train/highway/image_0191.jpg (deflated 0%)
# updating: content/data/train/highway/image_0062.jpg (deflated 3%)
# updating: content/data/train/highway/image_0099.jpg (deflated 3%)
# updating: content/data/train/highway/image_0044.jpg (deflated 3%)
# updating: content/data/train/highway/image_0057.jpg (deflated 2%)
# updating: content/data/train/highway/image_0146.jpg (deflated 1%)
# updating: content/data/train/highway/image_0173.jpg (stored 0%)
# updating: content/data/train/highway/image_0087.jpg (deflated 2%)
# updating: content/data/train/highway/image_0048.jpg (deflated 4%)
# updating: content/data/train/highway/image_0225.jpg (deflated 0%)
# updating: content/data/train/highway/image_0029.jpg (stored 0%)
# updating: content/data/train/highway/image_0246.jpg (stored 0%)
# updating: content/data/train/highway/image_0109.jpg (deflated 1%)
# updating: content/data/train/highway/image_0088.jpg (deflated 0%)
# updating: content/data/train/highway/image_0171.jpg (deflated 1%)
# updating: content/data/train/highway/image_0229.jpg (stored 0%)
# updating: content/data/train/highway/image_0184.jpg (stored 0%)
# updating: content/data/train/highway/image_0031.jpg (stored 0%)
# updating: content/data/train/highway/image_0155.jpg (deflated 0%)
# updating: content/data/train/highway/image_0005.jpg (deflated 1%)
# updating: content/data/train/highway/image_0080.jpg (stored 0%)
# updating: content/data/train/highway/image_0060.jpg (deflated 2%)
# updating: content/data/train/highway/image_0015.jpg (deflated 0%)
# updating: content/data/train/highway/image_0035.jpg (stored 0%)
# updating: content/data/train/highway/image_0153.jpg (deflated 1%)
# updating: content/data/train/highway/image_0125.jpg (deflated 0%)
# updating: content/data/train/highway/image_0250.jpg (stored 0%)
# updating: content/data/train/highway/image_0042.jpg (deflated 3%)
# updating: content/data/train/highway/image_0101.jpg (deflated 2%)
# updating: content/data/train/highway/image_0197.jpg (deflated 1%)
# updating: content/data/train/highway/image_0014.jpg (deflated 0%)
# updating: content/data/train/highway/image_0032.jpg (stored 0%)
# updating: content/data/train/highway/image_0150.jpg (stored 0%)
# updating: content/data/train/highway/image_0116.jpg (deflated 1%)
# updating: content/data/train/highway/image_0036.jpg (stored 0%)
# updating: content/data/train/highway/image_0247.jpg (stored 0%)
# updating: content/data/train/highway/image_0174.jpg (stored 0%)
# updating: content/data/train/highway/image_0214.jpg (stored 0%)
# updating: content/data/train/highway/image_0260.jpg (stored 0%)
# updating: content/data/train/highway/image_0100.jpg (deflated 3%)
# updating: content/data/train/highway/image_0216.jpg (stored 0%)
# updating: content/data/train/highway/image_0041.jpg (deflated 8%)
# updating: content/data/train/highway/image_0123.jpg (deflated 0%)
# updating: content/data/train/highway/image_0067.jpg (deflated 2%)
# updating: content/data/train/highway/image_0144.jpg (deflated 3%)
# updating: content/data/train/highway/image_0244.jpg (deflated 1%)
# updating: content/data/train/highway/image_0003.jpg (stored 0%)
# updating: content/data/train/highway/image_0131.jpg (deflated 2%)
# updating: content/data/train/highway/image_0121.jpg (deflated 0%)
# updating: content/data/train/highway/image_0233.jpg (deflated 0%)
# updating: content/data/train/highway/image_0208.jpg (stored 0%)
# updating: content/data/train/highway/image_0232.jpg (stored 0%)
# updating: content/data/train/highway/image_0011.jpg (stored 0%)
# updating: content/data/train/highway/image_0008.jpg (deflated 0%)
# updating: content/data/train/highway/image_0192.jpg (stored 0%)
# updating: content/data/train/highway/image_0075.jpg (deflated 0%)
# updating: content/data/train/highway/image_0124.jpg (deflated 0%)
# updating: content/data/train/highway/image_0017.jpg (deflated 0%)
# updating: content/data/train/highway/image_0218.jpg (stored 0%)
# updating: content/data/train/highway/image_0156.jpg (deflated 2%)
# updating: content/data/train/highway/image_0177.jpg (stored 0%)
# updating: content/data/train/highway/image_0119.jpg (deflated 0%)
# updating: content/data/train/highway/image_0071.jpg (deflated 0%)
# updating: content/data/train/highway/image_0259.jpg (stored 0%)
# updating: content/data/train/highway/image_0045.jpg (deflated 2%)
# updating: content/data/train/highway/image_0142.jpg (deflated 1%)
# updating: content/data/train/highway/image_0234.jpg (stored 0%)
# updating: content/data/train/highway/image_0105.jpg (deflated 2%)
# updating: content/data/train/highway/image_0139.jpg (deflated 1%)
# updating: content/data/train/highway/image_0135.jpg (deflated 0%)
# updating: content/data/train/highway/image_0039.jpg (deflated 3%)
# updating: content/data/train/highway/image_0068.jpg (deflated 0%)
# updating: content/data/train/highway/image_0013.jpg (deflated 0%)
# updating: content/data/train/highway/image_0141.jpg (deflated 1%)
# updating: content/data/train/highway/image_0027.jpg (stored 0%)
# updating: content/data/train/highway/image_0079.jpg (stored 0%)
# updating: content/data/train/highway/image_0074.jpg (deflated 2%)
# updating: content/data/train/highway/image_0025.jpg (stored 0%)
# updating: content/data/train/highway/image_0162.jpg (deflated 1%)
# updating: content/data/train/highway/image_0251.jpg (stored 0%)
# updating: content/data/train/highway/image_0085.jpg (deflated 3%)
# updating: content/data/train/highway/image_0096.jpg (deflated 3%)
# updating: content/data/train/highway/image_0236.jpg (stored 0%)
# updating: content/data/train/highway/image_0004.jpg (stored 0%)
# updating: content/data/train/highway/image_0180.jpg (stored 0%)
# updating: content/data/train/highway/image_0095.jpg (deflated 2%)
# updating: content/data/train/highway/image_0147.jpg (stored 0%)
# updating: content/data/train/highway/image_0002.jpg (deflated 1%)
# updating: content/data/train/highway/image_0161.jpg (stored 0%)
# updating: content/data/train/highway/image_0052.jpg (deflated 4%)
# updating: content/data/train/highway/image_0195.jpg (deflated 1%)
# updating: content/data/train/highway/image_0205.jpg (stored 0%)
# updating: content/data/train/highway/image_0006.jpg (stored 0%)
# updating: content/data/train/highway/image_0235.jpg (stored 0%)
# updating: content/data/train/highway/image_0203.jpg (stored 0%)
# updating: content/data/train/highway/image_0070.jpg (stored 0%)
# updating: content/data/train/highway/image_0211.jpg (stored 0%)
# updating: content/data/train/highway/image_0231.jpg (stored 0%)
# updating: content/data/train/highway/image_0200.jpg (deflated 2%)
# updating: content/data/train/suburb/ (stored 0%)
# updating: content/data/train/suburb/image_0034.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0023.jpg (stored 0%)
# updating: content/data/train/suburb/image_0001.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0148.jpg (stored 0%)
# updating: content/data/train/suburb/image_0210.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0239.jpg (stored 0%)
# updating: content/data/train/suburb/image_0108.jpg (stored 0%)
# updating: content/data/train/suburb/image_0053.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0065.jpg (stored 0%)
# updating: content/data/train/suburb/image_0137.jpg (stored 0%)
# updating: content/data/train/suburb/image_0140.jpg (stored 0%)
# updating: content/data/train/suburb/image_0081.jpg (stored 0%)
# updating: content/data/train/suburb/image_0228.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0043.jpg (stored 0%)
# updating: content/data/train/suburb/image_0127.jpg (stored 0%)
# updating: content/data/train/suburb/image_0040.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0189.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0196.jpg (stored 0%)
# updating: content/data/train/suburb/image_0188.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0077.jpg (stored 0%)
# updating: content/data/train/suburb/image_0167.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0164.jpg (stored 0%)
# updating: content/data/train/suburb/image_0185.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0022.jpg (stored 0%)
# updating: content/data/train/suburb/image_0187.jpg (stored 0%)
# updating: content/data/train/suburb/image_0172.jpg (stored 0%)
# updating: content/data/train/suburb/image_0138.jpg (stored 0%)
# updating: content/data/train/suburb/image_0220.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0084.jpg (stored 0%)
# updating: content/data/train/suburb/image_0241.jpg (stored 0%)
# updating: content/data/train/suburb/image_0213.jpg (stored 0%)
# updating: content/data/train/suburb/image_0117.jpg (stored 0%)
# updating: content/data/train/suburb/image_0222.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0083.jpg (stored 0%)
# updating: content/data/train/suburb/image_0215.jpg (stored 0%)
# updating: content/data/train/suburb/image_0082.jpg (stored 0%)
# updating: content/data/train/suburb/image_0069.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0168.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0194.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0061.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0149.jpg (stored 0%)
# updating: content/data/train/suburb/image_0198.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0024.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0212.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0226.jpg (stored 0%)
# updating: content/data/train/suburb/image_0028.jpg (stored 0%)
# updating: content/data/train/suburb/image_0033.jpg (stored 0%)
# updating: content/data/train/suburb/image_0026.jpg (stored 0%)
# updating: content/data/train/suburb/image_0176.jpg (stored 0%)
# updating: content/data/train/suburb/image_0160.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0120.jpg (stored 0%)
# updating: content/data/train/suburb/image_0183.jpg (stored 0%)
# updating: content/data/train/suburb/image_0178.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0020.jpg (stored 0%)
# updating: content/data/train/suburb/image_0059.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0046.jpg (deflated 2%)
# updating: content/data/train/suburb/image_0122.jpg (stored 0%)
# updating: content/data/train/suburb/image_0062.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0057.jpg (stored 0%)
# updating: content/data/train/suburb/image_0146.jpg (stored 0%)
# updating: content/data/train/suburb/image_0173.jpg (stored 0%)
# updating: content/data/train/suburb/image_0225.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0088.jpg (stored 0%)
# updating: content/data/train/suburb/image_0171.jpg (stored 0%)
# updating: content/data/train/suburb/image_0229.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0031.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0155.jpg (stored 0%)
# updating: content/data/train/suburb/image_0182.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0193.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0005.jpg (stored 0%)
# updating: content/data/train/suburb/image_0219.jpg (stored 0%)
# updating: content/data/train/suburb/image_0015.jpg (stored 0%)
# updating: content/data/train/suburb/image_0153.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0125.jpg (stored 0%)
# updating: content/data/train/suburb/image_0042.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0101.jpg (stored 0%)
# updating: content/data/train/suburb/image_0014.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0132.jpg (stored 0%)
# updating: content/data/train/suburb/image_0102.jpg (stored 0%)
# updating: content/data/train/suburb/image_0032.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0116.jpg (stored 0%)
# updating: content/data/train/suburb/image_0036.jpg (stored 0%)
# updating: content/data/train/suburb/image_0050.jpg (stored 0%)
# updating: content/data/train/suburb/image_0174.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0214.jpg (stored 0%)
# updating: content/data/train/suburb/image_0098.jpg (stored 0%)
# updating: content/data/train/suburb/image_0041.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0175.jpg (stored 0%)
# updating: content/data/train/suburb/image_0123.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0067.jpg (stored 0%)
# updating: content/data/train/suburb/image_0003.jpg (stored 0%)
# updating: content/data/train/suburb/image_0143.jpg (stored 0%)
# updating: content/data/train/suburb/image_0128.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0233.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0107.jpg (stored 0%)
# updating: content/data/train/suburb/image_0011.jpg (stored 0%)
# updating: content/data/train/suburb/image_0008.jpg (stored 0%)
# updating: content/data/train/suburb/image_0075.jpg (stored 0%)
# updating: content/data/train/suburb/image_0103.jpg (stored 0%)
# updating: content/data/train/suburb/image_0156.jpg (stored 0%)
# updating: content/data/train/suburb/image_0021.jpg (stored 0%)
# updating: content/data/train/suburb/image_0177.jpg (stored 0%)
# updating: content/data/train/suburb/image_0119.jpg (stored 0%)
# updating: content/data/train/suburb/image_0071.jpg (stored 0%)
# updating: content/data/train/suburb/image_0134.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0045.jpg (stored 0%)
# updating: content/data/train/suburb/image_0234.jpg (stored 0%)
# updating: content/data/train/suburb/image_0094.jpg (stored 0%)
# updating: content/data/train/suburb/image_0139.jpg (stored 0%)
# updating: content/data/train/suburb/image_0068.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0013.jpg (stored 0%)
# updating: content/data/train/suburb/image_0079.jpg (stored 0%)
# updating: content/data/train/suburb/image_0074.jpg (stored 0%)
# updating: content/data/train/suburb/image_0202.jpg (stored 0%)
# updating: content/data/train/suburb/image_0009.jpg (stored 0%)
# updating: content/data/train/suburb/image_0199.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0025.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0223.jpg (stored 0%)
# updating: content/data/train/suburb/image_0012.jpg (stored 0%)
# updating: content/data/train/suburb/image_0111.jpg (stored 0%)
# updating: content/data/train/suburb/image_0162.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0154.jpg (stored 0%)
# updating: content/data/train/suburb/image_0236.jpg (stored 0%)
# updating: content/data/train/suburb/image_0004.jpg (stored 0%)
# updating: content/data/train/suburb/image_0152.jpg (stored 0%)
# updating: content/data/train/suburb/image_0181.jpg (deflated 1%)
# updating: content/data/train/suburb/image_0180.jpg (stored 0%)
# updating: content/data/train/suburb/image_0147.jpg (stored 0%)
# updating: content/data/train/suburb/image_0161.jpg (stored 0%)
# updating: content/data/train/suburb/image_0179.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0166.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0186.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0195.jpg (stored 0%)
# updating: content/data/train/suburb/image_0037.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0205.jpg (stored 0%)
# updating: content/data/train/suburb/image_0118.jpg (stored 0%)
# updating: content/data/train/suburb/image_0227.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0203.jpg (stored 0%)
# updating: content/data/train/suburb/image_0070.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0018.jpg (deflated 0%)
# updating: content/data/train/suburb/image_0200.jpg (deflated 0%)
# updating: content/data/train/mountain/ (stored 0%)
# updating: content/data/train/mountain/image_0230.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0252.jpg (stored 0%)
# updating: content/data/train/mountain/image_0034.jpg (stored 0%)
# updating: content/data/train/mountain/image_0023.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0001.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0007.jpg (stored 0%)
# updating: content/data/train/mountain/image_0086.jpg (stored 0%)
# updating: content/data/train/mountain/image_0262.jpg (stored 0%)
# updating: content/data/train/mountain/image_0331.jpg (stored 0%)
# updating: content/data/train/mountain/image_0270.jpg (stored 0%)
# updating: content/data/train/mountain/image_0148.jpg (stored 0%)
# updating: content/data/train/mountain/image_0266.jpg (stored 0%)
# updating: content/data/train/mountain/image_0210.jpg (stored 0%)
# updating: content/data/train/mountain/image_0201.jpg (stored 0%)
# updating: content/data/train/mountain/image_0240.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0239.jpg (stored 0%)
# updating: content/data/train/mountain/image_0114.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0108.jpg (stored 0%)
# updating: content/data/train/mountain/image_0063.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0090.jpg (stored 0%)
# updating: content/data/train/mountain/image_0053.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0307.jpg (stored 0%)
# updating: content/data/train/mountain/image_0113.jpg (stored 0%)
# updating: content/data/train/mountain/image_0049.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0065.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0257.jpg (stored 0%)
# updating: content/data/train/mountain/image_0353.jpg (stored 0%)
# updating: content/data/train/mountain/image_0140.jpg (stored 0%)
# updating: content/data/train/mountain/image_0081.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0157.jpg (stored 0%)
# updating: content/data/train/mountain/image_0043.jpg (deflated 1%)
# updating: content/data/train/mountain/image_0297.jpg (stored 0%)
# updating: content/data/train/mountain/image_0127.jpg (stored 0%)
# updating: content/data/train/mountain/image_0245.jpg (stored 0%)
# updating: content/data/train/mountain/image_0366.jpg (deflated 1%)
# updating: content/data/train/mountain/image_0040.jpg (stored 0%)
# updating: content/data/train/mountain/image_0072.jpg (stored 0%)
# updating: content/data/train/mountain/image_0189.jpg (stored 0%)
# updating: content/data/train/mountain/image_0277.jpg (stored 0%)
# updating: content/data/train/mountain/image_0196.jpg (stored 0%)
# updating: content/data/train/mountain/image_0091.jpg (deflated 2%)
# updating: content/data/train/mountain/image_0188.jpg (stored 0%)
# updating: content/data/train/mountain/image_0309.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0077.jpg (stored 0%)
# updating: content/data/train/mountain/image_0038.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0190.jpg (stored 0%)
# updating: content/data/train/mountain/image_0076.jpg (deflated 2%)
# updating: content/data/train/mountain/image_0051.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0022.jpg (stored 0%)
# updating: content/data/train/mountain/image_0187.jpg (stored 0%)
# updating: content/data/train/mountain/image_0293.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0172.jpg (stored 0%)
# updating: content/data/train/mountain/image_0030.jpg (stored 0%)
# updating: content/data/train/mountain/image_0255.jpg (stored 0%)
# updating: content/data/train/mountain/image_0064.jpg (stored 0%)
# updating: content/data/train/mountain/image_0213.jpg (stored 0%)
# updating: content/data/train/mountain/image_0010.jpg (stored 0%)
# updating: content/data/train/mountain/image_0286.jpg (deflated 0%)
# updating: content/data/train/mountain/image_0117.jpg (stored 0%)
# updating: content/data/train/mountain/image_0351.jpg (deflated 1%)
# updating: content/data/train/mountain/image_0222.jpg (stored 0%)
# ...
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_data_transforms.cpython-36.pyc (deflated 45%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_dl_utils.cpython-38-pytest-6.0.2.pyc (deflated 51%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_my_alexnet.cpython-37.pyc (deflated 32%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_models.cpython-38.pyc (deflated 37%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_my_alexnet.cpython-37-pytest-6.0.1.pyc (deflated 41%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_stats_helper.cpython-36.pyc (deflated 36%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_models.cpython-36.pyc (deflated 37%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_checkpoints.cpython-37-pytest-6.0.2.pyc (deflated 75%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_base.cpython-36.pyc (deflated 31%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_stats_helper.cpython-37-pytest-6.0.1.pyc (deflated 46%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_my_alexnet.cpython-37-pytest-6.0.2.pyc (deflated 41%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_models.cpython-37-pytest-6.0.1.pyc (deflated 38%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_simple_net_dropout.cpython-37.pyc (deflated 37%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/__init__.cpython-36.pyc (deflated 27%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_models.cpython-37-pytest-6.0.2.pyc (deflated 38%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_simple_net_dropout.cpython-36.pyc (deflated 36%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_data_transforms.cpython-38-pytest-6.0.2.pyc (deflated 42%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_image_loader.cpython-38-pytest-6.0.2.pyc (deflated 57%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_simple_net.cpython-37-pytest-6.0.1.pyc (deflated 46%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_data_transforms.cpython-37.pyc (deflated 45%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_simple_net.cpython-38.pyc (deflated 35%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_dl_utils.cpython-37-pytest-6.0.2.pyc (deflated 52%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_base.cpython-37-pytest-6.0.1.pyc (deflated 32%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_simple_net.cpython-38-pytest-6.0.2.pyc (deflated 45%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/__init__.cpython-38.pyc (deflated 24%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_checkpoints.cpython-38.pyc (deflated 55%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_simple_net_dropout.cpython-37-pytest-6.0.1.pyc (deflated 43%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_base.cpython-37-pytest-6.0.2.pyc (deflated 32%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_image_loader.cpython-37-pytest-6.0.2.pyc (deflated 59%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_base.cpython-38-pytest-6.0.2.pyc (deflated 32%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_models.cpython-37.pyc (deflated 38%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_data_transforms.cpython-37-pytest-6.0.2.pyc (deflated 43%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_image_loader.cpython-36.pyc (deflated 58%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_my_alexnet.cpython-38.pyc (deflated 33%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_image_loader.cpython-37.pyc (deflated 57%)
# updating: content/proj2_code/proj2_unit_tests/__pycache__/test_image_loader.cpython-37-pytest-6.0.1.pyc (deflated 59%)
# updating: content/proj2_code/proj2_unit_tests/test_dl_utils.py (deflated 61%)
# updating: content/proj2_code/proj2_unit_tests/test_checkpoints.py (deflated 77%)
# updating: content/proj2_code/proj2_unit_tests/test_simple_net.py (deflated 47%)
# updating: content/proj2_code/proj2_unit_tests/__init__.py (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/test_simple_net_dropout.py (deflated 49%)
# updating: content/proj2_code/proj2_unit_tests/test_my_alexnet.py (deflated 45%)
# updating: content/proj2_code/proj2_unit_tests/test_data_transforms.py (deflated 65%)
# updating: content/proj2_code/proj2_unit_tests/small_data/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/insidecity/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/insidecity/image_0001.jpg (deflated 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/insidecity/image_0002.jpg (deflated 2%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/office/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/office/image_0001.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/office/image_0003.jpg (deflated 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/highway/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/highway/image_0001.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/highway/image_0002.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/suburb/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/suburb/image_0001.jpg (deflated 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/suburb/image_0003.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/mountain/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/mountain/image_0001.jpg (deflated 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/mountain/image_0003.jpg (deflated 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/opencountry/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/opencountry/image_0001.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/opencountry/image_0002.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/industrial/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/industrial/image_0001.jpg (deflated 4%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/industrial/image_0003.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/forest/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/forest/image_0001.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/forest/image_0002.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/store/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/store/image_0003.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/store/image_0002.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/kitchen/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/kitchen/image_0003.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/kitchen/image_0002.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/street/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/street/image_0007.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/street/image_0006.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/tallbuilding/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/tallbuilding/image_0001.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/tallbuilding/image_0002.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/coast/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/coast/image_0001.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/coast/image_0002.jpg (deflated 3%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/bedroom/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/bedroom/image_0003.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/bedroom/image_0004.jpg (deflated 5%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/livingroom/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/livingroom/image_0003.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/train/livingroom/image_0002.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/insidecity/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/insidecity/image_0005.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/insidecity/image_0009.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/office/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/office/image_0008.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/office/image_0002.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/highway/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/highway/image_0010.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/highway/image_0009.jpg (deflated 2%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/suburb/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/suburb/image_0002.jpg (deflated 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/suburb/image_0006.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/mountain/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/mountain/image_0024.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/mountain/image_0002.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/opencountry/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/opencountry/image_0020.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/opencountry/image_0003.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0022.jpg (deflated 16%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0010.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0014.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0019.jpg (deflated 2%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0011.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0009.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0012.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0004.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0002.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/industrial/image_0018.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/forest/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/forest/image_0003.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/forest/image_0004.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/store/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/store/image_0001.jpg (deflated 4%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/store/image_0005.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/kitchen/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/kitchen/image_0001.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/kitchen/image_0004.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/street/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/street/image_0001.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/street/image_0002.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/tallbuilding/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/tallbuilding/image_0010.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/tallbuilding/image_0011.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/coast/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/coast/image_0010.jpg (deflated 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/coast/image_0015.jpg (deflated 3%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/coast/image_0006.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/bedroom/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/bedroom/image_0001.jpg (deflated 4%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/bedroom/image_0002.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/livingroom/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/livingroom/image_0001.jpg (deflated 1%)
# updating: content/proj2_code/proj2_unit_tests/small_data/test/livingroom/image_0006.jpg (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/test_image_loader.py (deflated 81%)
# updating: content/proj2_code/proj2_unit_tests/test_data/ (stored 0%)
# updating: content/proj2_code/proj2_unit_tests/test_data/transform_out.pt (deflated 65%)
# updating: content/proj2_code/proj2_unit_tests/test_data/transform_inp.txt (deflated 94%)
# updating: content/proj2_code/proj2_unit_tests/test_data/sample_inp.txt (deflated 94%)
# updating: content/proj2_code/proj2_unit_tests/test_stats_helper.py (deflated 54%)
# updating: content/proj2_code/.ipynb_checkpoints/ (stored 0%)
# updating: content/proj2_code/.ipynb_checkpoints/proj2_part2-checkpoint.ipynb (deflated 73%)
# updating: content/proj2_code/data_transforms.py (deflated 78%)
# updating: content/proj2_code/optimizer.py (deflated 64%)
# updating: content/proj2_code/dl_utils.py (deflated 73%)
# updating: content/proj2_code/my_alexnet.py (deflated 67%)
# updating: content/proj2_code/proj2_part2.ipynb (deflated 73%)
# updating: content/proj2_code/simple_net_ablation.py (deflated 73%)
# updating: content/6476_Fall2020_proj2.egg-info/ (stored 0%)
# updating: content/6476_Fall2020_proj2.egg-info/SOURCES.txt (deflated 74%)
# updating: content/6476_Fall2020_proj2.egg-info/PKG-INFO (deflated 40%)
# updating: content/6476_Fall2020_proj2.egg-info/top_level.txt (stored 0%)
# updating: content/6476_Fall2020_proj2.egg-info/dependency_links.txt (stored 0%)
# updating: content/6476_Fall2020_proj2.egg-info/requires.txt (stored 0%)
# updating: content/dataset.png (deflated 0%)
# updating: content/zip_submission.py (deflated 65%)
# updating: content/proj2_template.pptx (deflated 11%)
# updating: content/setup.py (deflated 47%)
#   adding: content/model_checkpoints/simple_net_ablation/checkpoint.pt (deflated 8%)
#   adding: content/proj2_code/__pycache__/simple_net_ablation.cpython-36.pyc (deflated 40%)

# %%
from google.colab import files
files.download("/content/file.zip")

# %% [markdown]
# **TODO 15**: Like both previous sections, you are required to pass a threshold of **85%** for this part. Copy the plots and values onto the report and answer questions accordingly.

# %% [markdown]
# If you are doing this project individually, you have completed all the compulsory portion of the project code.
#
# Please review the rubric before proceeding to extra credits. Note that extra-credits require more effort per grade point than regular credits, so please do not worry if you cannot finish them. That being said, extra-credits are designed to enchance the learning on the topic, and you might want to review it.
#
# **Note:** EC1 is compulsory for students doing this project in pairs.

# %% [markdown]
# ## Extra Credit 1 Ablation Studies for SimpleNet

# %% [markdown]
# After you have implemented the SimpleNet and play with the parameters, you have a better understanding of Convolutional Neural Network. Now let's do some ablation studies about the simple net. How those parameters will influence the performance of your simple network?
#
# **Hint:** you can think about kernel size, number of convolutional layers, fully connected layers, normalization layers, the input image size.
#
# You need to perform atleast 3 ablation studies and analyse the accuracy as well as the training/inference time. Please keep track of your experiments and the results as you are required to add them to the report. The experiments should demonstrate an effect on accuracy/timing and you need to provide your reasoning behind it. Your thought process and experiment design is more important than getting _correct observations_.

# %% [markdown]
# **TODO EC1** Please fill the ```optimizer_config``` in the next cell with well-tuned parameter same with the value for your simple net. Change the model structure from ```SimpleNet``` in ```simple_net_ablation.py```. you will need to fill the ```__init__``` and ```forward``` in that file like what you did previously but with different hyperparameters.
#
# Repeat this TODO multiple times to perform 3 studies.

# %%
inp_size = (64,64)
optimizer_config = {
  "optimizer_type": "sgd",
  "lr": 5e-3,
  "weight_decay": 3e-4
}

# %%
import time

def eval_time(model: torch.nn.Module, input_tensor: torch.Tensor):
    model.eval()
    start = time.time()
    for _ in range(100):
        model(input_tensor)
    end = time.time()
    return (end-start)/100

def print_time(model1: torch.nn.Module, model2: torch.nn.Module, input_tensor: torch.Tensor):
    print("The time taken for original simple net is {:.9f}".format(eval_time(model1, input_tensor)))
    print("The time taken for ablated simple net is {:.9f}".format(eval_time(model2, input_tensor)))

# %%
simple_model = SimpleNet()
optimizer = get_optimizer(simple_model, optimizer_config)

trainer = Trainer(data_dir=data_base_path, 
                  model = simple_model,
                  optimizer = optimizer,
                  model_dir = os.path.join(model_base_path, 'simple_net'),
                  train_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  test_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  batch_size = 15,
                  load_from_disk = True,
                  cuda = is_cuda
                 )
_, accuracy = trainer.evaluate()

print(accuracy)
# Out:
# 0.49533333333333335

# %%
from proj2_code.simple_net_ablation import SimpleNetAblation

simple_model_ablation = SimpleNetAblation()
optimizer_ablation = get_optimizer(simple_model_ablation, optimizer_config)

trainer_ablation = Trainer(data_dir=data_base_path, 
                  model = simple_model_ablation,
                  optimizer = optimizer_ablation,
                  model_dir = os.path.join(model_base_path, 'simple_net_ablation'),
                  train_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  test_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  batch_size = 15,
                  load_from_disk = False,
                  cuda = is_cuda
                 )

# %%
ablation_train_start = time.time()
trainer_ablation.train(num_epochs=30)
ablation_train_end = time.time()
print("The training time taken for tuned simple net is {:.9f}".format(ablation_train_end-ablation_train_start))
# Out:
# Epoch:0, Training Loss:2.7042, Validation Loss:2.7095
# Epoch:1, Training Loss:2.6081, Validation Loss:2.6688
# Epoch:2, Training Loss:2.4815, Validation Loss:2.5755
# Epoch:3, Training Loss:2.3578, Validation Loss:2.4335
# Epoch:4, Training Loss:2.2337, Validation Loss:2.3212
# Epoch:5, Training Loss:2.1124, Validation Loss:2.2150
# Epoch:6, Training Loss:2.0682, Validation Loss:2.2192
# Epoch:7, Training Loss:1.8590, Validation Loss:1.9882
# Epoch:8, Training Loss:1.7783, Validation Loss:1.9772
# Epoch:9, Training Loss:1.6183, Validation Loss:1.8230
# Epoch:10, Training Loss:1.5608, Validation Loss:1.7983
# Epoch:11, Training Loss:1.5866, Validation Loss:1.8537
# Epoch:12, Training Loss:1.4666, Validation Loss:1.7875
# Epoch:13, Training Loss:1.4001, Validation Loss:1.7160
# Epoch:14, Training Loss:1.5340, Validation Loss:1.9154
# Epoch:15, Training Loss:1.3579, Validation Loss:1.7416
# Epoch:16, Training Loss:1.2433, Validation Loss:1.6450
# Epoch:17, Training Loss:1.2086, Validation Loss:1.6866
# Epoch:18, Training Loss:1.1548, Validation Loss:1.6501
# Epoch:19, Training Loss:1.0936, Validation Loss:1.6009
# Epoch:20, Training Loss:1.0277, Validation Loss:1.6158
# Epoch:21, Training Loss:0.9625, Validation Loss:1.5972
# Epoch:22, Training Loss:0.9218, Validation Loss:1.5391
# Epoch:23, Training Loss:0.9061, Validation Loss:1.6785
# Epoch:24, Training Loss:0.8042, Validation Loss:1.5612
# Epoch:25, Training Loss:0.8718, Validation Loss:1.6446
# Epoch:26, Training Loss:0.7487, Validation Loss:1.6736
# Epoch:27, Training Loss:0.7139, Validation Loss:1.6495
# Epoch:28, Training Loss:0.6270, Validation Loss:1.6110
# Epoch:29, Training Loss:0.7636, Validation Loss:1.8387
# Epoch:30, Training Loss:0.6283, Validation Loss:1.7672
# The training time taken for tuned simple net is 275.114424706

# %%
_, accuracy_ablation = trainer_ablation.evaluate()
print(accuracy_ablation)
# Out:
# 0.47

# %%
trainer_ablation.plot_loss_history()
trainer_ablation.plot_accuracy()

# %%
sample_input, _ = next(iter(image_loader))
sample_input = sample_input.unsqueeze(0)

if is_cuda:
    sample_input = sample_input.to('cuda')

print_time(simple_model, simple_model_ablation, sample_input)
# Out:
# The time taken for original simple net is 0.000454552
# The time taken for ablated simple net is 0.000466104

# %% [markdown]
# ## Extra Credit 2: Model Space/Compute improvement
#
# We have created the AlexNet model which performs really well. But can we deploy on a robot which does not have access to powerful GPUs. What if we want to make the model simpler and faster for inference. One option will be to use SimpleNet or a variant of it. But that has very low accuracy compared to AlexNet.
#
# Can we utilize the AlexNet model which we have learnt and improve the memory/compute usage? This is an active research area with [several possible options](https://arxiv.org/pdf/1710.09282.pdf).
#
# In this part, we will try quantizing our filter weights from 32-bit floating point to 8-bit integer. As you can guess, all the weights in the layers (in convolution and fully connected layers) will have a 75% reduction from this simple switch.
#
# What about compute time? The first benefit is directly from lower memory foot-print. We can transfer more weights in the fixed memory bandwith and the cache can hold more weights too. Some CPU architectures might have INT8 computation units which can offer more speedup.
#
# We might lose some accuracy when we sacrifice precision. Doing the fp32->int8 conversion directly is a bad choice.
# Suppose an activation is in a small range of $[0.1, 0.2]$. We cannot just round the weights as the activation might be the same for all the inputs. Hence we need to quantize based on the statistics of the activations.
#
# This is a very brief introduction, and we expect you to read material online to complete this section.
# [Pytorch's Introduction to Quantization](https://pytorch.org/blog/introduction-to-quantization-on-pytorch/) is a good starting point. We used the post-training static quantization scheme and got good performance. You are free to use any quantization scheme as long as it falls within one of the buckes of the rubric.
#
# **TODO EC2.1**: Write the ```forward``` function in ```my_alexnet_quantized.py```. Do remember that the input and the output of the function will not be quantized and you need to pass them through a layer for quantization/dequantization.
#
#
# **TODO EC2.2**: Write the ```quantize_model``` function in ```quantization.py```.
#
# **Grading**: There are no unit tests for this portion. You will be required to write your idea, paste code snippets, and results in the report. The rubric for this section is a bit complicated and it is recommended to review it before proceeding further.
#
# Please note that not all possible buckets may be possible to achieve using simple post-training static quantization scheme. You can obtain a decent performance here and come back later if you are inclined. Make sure you understand what you are doing as 2 points will be alloted for that.

# %%
from proj2_code.quantization import quantize_model

# %%
inp_size = (224, 224)

# %%
original_model = MyAlexNet().to('cpu')

# %%
alexnet_trainer = Trainer(data_dir=data_base_path, 
                  model = original_model,
                  optimizer = get_optimizer(original_model, optimizer_config),
                  model_dir = os.path.join(model_base_path, 'alexnet'),
                  train_data_transforms = get_data_augmentation_transforms(inp_size, dataset_mean, dataset_std),
                  test_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  batch_size = 32,
                  load_from_disk = True,
                  cuda = False
                 )

# %%
image_loader = ImageLoader(data_base_path, 
                           split='train', 
                           transform=get_fundamental_transforms(inp_size, dataset_mean, dataset_std)
                          )

# %%
quantized_alexnet = quantize_model(original_model, image_loader)

# %%
quantized_alexnet_trainer = Trainer(data_dir=data_base_path, 
                  model = quantized_alexnet,
                  optimizer = get_optimizer(original_model, optimizer_config),
                  model_dir = os.path.join(model_base_path, 'quantized_alexnet'),
                  train_data_transforms = get_data_augmentation_transforms(inp_size, dataset_mean, dataset_std),
                  test_data_transforms = get_fundamental_transforms(inp_size, dataset_mean, dataset_std),
                  batch_size = 32,
                  load_from_disk = False,
                  cuda = False
                 )

quantized_alexnet_trainer.save_model()

# %% [markdown]
# ### Size comparison

# %%
quantized_alexnet_size = os.path.getsize(os.path.join(model_base_path, 'quantized_alexnet', 'checkpoint.pt'))/1e6
alexnet_size = os.path.getsize(os.path.join(model_base_path, 'alexnet', 'checkpoint.pt'))/1e6

# %%
print('Original Alexnet Size: {:.2f}'.format(alexnet_size))
print('Quantized Alexnet Size: {:.2f}'.format(quantized_alexnet_size))
print('Percentage reduction: {:.2f}%'.format(100-100*quantized_alexnet_size/alexnet_size))

# %% [markdown]
# Now let's have your model predict on some examples and see how well it performs qualitatively.

# %% [markdown]
# ### Speed comparison

# %%
import time

def time_forward_pass(model: torch.nn.Module, input_tensor: torch.tensor) -> float:
    model.eval()
    start = time.time()
    for _ in range(300):
        model(input_tensor)
    end = time.time()
    
    return (end-start)/300

# %%
sample_input, _ = next(iter(image_loader))
sample_input = sample_input.unsqueeze(0)

# %%
quantized_alexnet_time = time_forward_pass(quantized_alexnet, sample_input)

# %%
alexnet_time = time_forward_pass(original_model, sample_input)

# %%
print('Original Alexnet Time: {:.2f}'.format(alexnet_time))
print('Quantized Alexnet Time: {:.2f}'.format(quantized_alexnet_time))
print('Percentage reduction: {:.2f}%'.format(100-100*quantized_alexnet_time/alexnet_time))

# %%
_, alexnet_accuracy = alexnet_trainer.evaluate()
_, quantized_alexnet_accuracy = quantized_alexnet_trainer.evaluate()

# %%
print('Original Alexnet Accuracy: {:.2f}'.format(alexnet_accuracy))
print('Quantized Alexnet Accuracy: {:.2f}'.format(quantized_alexnet_accuracy))
print('Percentage reduction: {:.2f}%'.format(100-100*quantized_alexnet_accuracy/alexnet_accuracy))

# %% [markdown]
# ### Extra Credit 3 Classification Performance Analysis
#
# In this part, you will need to analyze the performance of your models by evaluating your model's predictions. To do that, you could use the metrics scores, such as precision, recall, F1 score, confusion matrix, etc. Since we care more about your reasoning and reflection here, you can directly use functions from `sklear.metrics`. You can find the list of available metrics and what each one is assessing [here](https://scikit-learn.org/stable/modules/model_evaluation.html#classification-metrics).
#
# **TODO EC3.1:** implement the function `evaluate` in `analyze.py`. Then use metrics scores returned by this function to evaluate the quality of predictions on the **test** split for `SimpleNet`, `SimpleNetDropout`, and `MyAlexNet`, anaylze the performance of the models, and put your analysis in the report.
#
# Here, we ask you to compute the confusion matrix as one of the metrics. You don't have to compute it manually, instead, you could use the function from `sklearn.metrics` or `PyCM`. You can refer to the documentation of [the sklearn function](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html), or if you prefer `PyCM` package, you can refer to its [full documentation](https://www.pycm.ir/doc/index.html#Usage) or [an example of usage](https://www.pycm.ir/doc/Example1.html). You could also learn more about the confusion matrix itself in its [wiki](https://en.wikipedia.org/wiki/Confusion_matrix).
#
# Besides the confusion matrix, you also need to use at least 1 and at most 3 additional metrics of your own choise. You don't need to compute any metrics manually, instead, you could just call the functions from `sklearn.metrics`. Since accuracy is already reported during training, accuracy will **NOT** count in this part, but you can use it in your analysis.
#
# You need to do two things in your `evaluate` function.
# 1. compute the confusion matrix and return it
# 2. compute 1 to 3 additional metrics scores and return them.
#
# Note that your code is not the main issue here as you are free to use third party modules. Please make sure you understand what the results mean and you can reflect on the observations.
#
# **TODO EC3.2:** please answer the following questions in your report.
# * What are your confusion matrices for each model? What information do they give you and what do you think about it?
# * What additional metrics are you using? What are the scores and how are they evaluating the model's performance? What do you think could possibly improve the performance?
#
# **Grading**: There are no unit tests for this portion. You will be required to write your idea and results in the report.

# %%
# will need to run this on Colab as we are not using conda environment
# !pip install pycm
# !pip install sklearn
# Out:
# Requirement already satisfied: pycm in /usr/local/lib/python3.6/dist-packages (2.9)
# Requirement already satisfied: art>=1.8 in /usr/local/lib/python3.6/dist-packages (from pycm) (4.8)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pycm) (1.18.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.16.0)

# %%
from proj2_code.analyze import evaluate

# %%
# get image loader
inp_size = (64, 64)
image_loader = ImageLoader(data_base_path,
                           split='test',
                           transform=get_fundamental_transforms(inp_size, dataset_mean, dataset_std)
                          )

# %%
### Evaluate SimpleNet ###
# Load the model from saved checkpoints
simple_net = SimpleNet()
model_dir = os.path.join(model_base_path, 'simple_net', 'checkpoint.pt')

# evaluate the model
metrics_list = []
metrics_args = []
cm, scores = evaluate(simple_net, image_loader, is_cuda, metrics_list, metrics_args, model_dir)

# %%
### Student TODO: you can print the confusion matrix and evaluation scores here ###
print(cm)
print(scores)

# %%
### Evaluate SimpleNetDropout ###

# Load the model from saved checkpoints
simple_net_dropout = SimpleNetDropout()
model_dir = os.path.join(model_base_path, 'simple_net_dropout', 'checkpoint.pt')

metrics_list = []
metrics_args = []
cm, scores = evaluate(simple_net_dropout, image_loader, is_cuda, metrics_list, metrics_args, model_dir)

# %%
### Student TODO: you can print the confusion matrix and evaluation scores here ###
print(cm)
print(scores)

# %%
# get image loader
inp_size = (224, 224)
image_loader = ImageLoader(data_base_path,
                           split='test',
                           transform=get_fundamental_transforms(inp_size, dataset_mean, dataset_std)
                          )

# %%
### Evaluate MyAlexNet ###

# Load the model from saved checkpoints
my_alexnet = MyAlexNet()
model_dir = os.path.join(model_base_path, 'alexnet', 'checkpoint.pt')

metrics_list = []
metrics_args = []
cm, scores = evaluate(my_alexnet, image_loader, is_cuda, metrics_list, metrics_args, model_dir)

# %%
### Student TODO: you can print the confusion matrix and evaluation scores here ###

# %% [markdown]
# ## Code testing
# We have provided a set of tests for you to evaluate your implementation. We have included tests inside ```proj2.ipynb``` so you can check your progress as you implement each section. At the end, you should call the tests from the terminal using the command ```pytest proj2_code/proj2_unit_tests/```

# %% [markdown]
# ## Submission
#
# This is very important as you will lose 5 points for every time you do not follow the instructions.
#
# Do install any additional packages inside the conda environment. The TAs will use the same environment as defined in the config files we provide you, so anything that's not in there by default will probably cause your code to break during grading. Do use absolute paths in your code or your code will break. Use relative paths like the starter code already does. Failure to follow any of these instructions will lead to point deductions. Create the zip file using ```python zip_submission.py --gt_username <your_gt_username>``` (it will zip up the appropriate directories/files for you!) and hand it through Gradescope. Remember to submit your report as a PDF to Gradescope as well.

# %% [markdown]
# ## Rubric
# We have covered 35 credits in part 1 code. The overall rubric division for this part is:
#
# | Submission Type | Credit Type | Individual | Partner |
# | --------------- | ----------- | ---------- | ------- |
# | Code            | Mandatory   | 25         | 20      |
# | Report          | Mandatory   | 40         | 40      |
# | Report          | EC1         | 4          | 4       |
# | Report          | EC2         | 9          | 9       |
# | Report          | EC3         | 4          | 4       |
# | Total           |             | 82         | 77      |
#
#
# However, the max score for the this part is **capped at 77** for both individual and partner submissions. Hence individual submissions need not do all ECs for maximum possible credits.
#
#
#
# | Test name | Individual Scores | Partner Scores |
# | --------- | ----------------- | -------------- |
# | `test_simple_net_dropout` | 12 | 10 |
# |`test_my_alexnet` | 13 | 10 |
#
# **Rubric for EC2:**
# - +2 points for describing the strategy and explaining the main ideas in the report.
#
# Your results will fall in only one of these buckets. All the conditions in the bucket have to be satisfied to gain the points
# - +1 points for achieving >70% reduction in size, >20% reduction in speed, <10% reduction in accuracy
# - +2 points for achieving >70% reduction in size, >20% reduction in speed, <3% reduction in accuracy
# - +4 points for achieving >70% reduction in size, >20% reduction in speed, <0.75% reduction in accuracy
# - +4 points for achieving >70% reduction in size, >70% reduction in speed, <2% reduction in accuracy

# %% [markdown]
# ## Credit
#
# Assignment developed by Ayush Baid, Haoxin Ma, Jing Wu and Frank Dellaert, based on a the original assigment by Ayush Baid, Cusuh Ham, Jonathan Balloch, Shenhao Jiang, Frank Dellaert, and James Hays.
